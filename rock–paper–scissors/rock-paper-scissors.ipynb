# %% [markdown]
# # Rock Paper Scissors
#
# Let's play the famous game against our computer.
#
# https://en.wikipedia.org/wiki/Rock%E2%80%93paper%E2%80%93scissors
#
# The use of functions is recommended
#
# ## Goals
# 1. Use of loop
# 2. Data capture by console
# 3. Use if-elif-else
# 4. Use of try-except
# 5. Definition of functions. Modular programming
# 6. Logical operators.
# 7. Print
# 8. Import modules

# %%
# Import the choice function of the random module
# https://stackoverflow.com/questions/306400/how-to-randomly-select-an-item-from-a-list

import random

# Assign to a list the 3 possible options: 'stone', 'paper' or 'scissors'.

sps=['stone', 'paper', 'scissors']

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...

max_games = 5

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games

to_win = 3

# Define a function that randomly returns one of the 3 options.
# This will correspond to the play of the machine. Totally random.

def rdm():
    global cpu_option
    cpu_option = random.choice(sps)

# %%
# Define a function that asks your choice: 'stone', 'paper' or 'scissors'
# you should only allow one of the 3 options. This is defensive programming.
# If it is not stone, paper or scissors keep asking until it is.

def human():
    global human_option
    human_option = input('Choose stone, paper or scissors: ')

    while human_option not in sps:
        human_option = input("Choose stone, paper or scissors: ")
  
    
    
# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins

def combat():
    
    if human_option == cpu_option:
        return 0
    elif human_option == 'stone':
        if cpu_option == 'paper':
            return 1
        if cpu_option == 'scissors':
            return 2
    elif human_option == 'paper':
        if cpu_option == 'scissors':
            return 1
        if cpu_option == 'stone':
            return 2
    elif human_option == 'scissors':
        if cpu_option == 'stone':
            return 1
        if cpu_option == 'paper':
            return 2

# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

def choices ():
    print('Cpu: ', cpu_option)
    print('You: ' ,human_option)
    print('CPU: ',  cpu_wins, '  ','YOU: ', human_wins, '  ', 'Ties: ', ties)

    
# Create two variables that accumulate the wins of each participant

cpu_wins = 0
human_wins = 0
ties = 0



# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
#Print by console the winner of the game based on who has more accumulated wins

while ((cpu_wins + human_wins) < max_games) and (cpu_wins < to_win) and (human_wins < to_win):
    
    rdm()
    
    human()
    
    combat()

    if combat() == 1:
        cpu_wins = cpu_wins + 1
        
    elif combat() == 2:
        human_wins = human_wins + 1
        
    elif combat() == 0:
        ties = ties + 1
    
    choices()
    
if cpu_wins > human_wins:
    print ('CPU WINS')
elif human_wins > cpu_wins:
    print ('YOU WIN')

# %% [markdown]
# # Bonus: Stone, paper, scissors, lizard, spock
#
# Now the improvement begins.
#
# ![](images/rpsls.jpg)
#
#
# http://www.samkass.com/theories/RPSSL.html
#
# You are asked to impliment some improvements with respect to the simple previous game. In addition, the number of games (which must be ODD) will be requested per console until a valid number is entered.
#
# Improvements:
# * 5 options: stone, paper, scissors, lizard, spock
# * The number of games is requested per console
# Tip: Reuse code that you already use. If you have programmed intelligently, the bonus are simple modifications to the original game.

# %%
# Import the choice function of the random module

import random 
odds=[1,3,5,7,9]

def odd_number():
    global odd_num
    odd_num = random.choice(odds)
    print(odd_num)
      
# Define a function that asks for an odd number on the keyboard, until it is not valid
# will keep asking

def human_odd():
        
    global num_guess
    num_guess = int(input('Choose the number of games (odd number 1 to 9): '))

    while num_guess != odd_num:
        num_guess = int(input("Choose the number of games (odd number 1 to 9): "))
              
    else: 
        print('Thats right!')
        
odd_number()

human_odd()

# Assign a list of 5 possible options.

spsls = ['stone', 'paper', 'scissors', 'lizard', 'spock']

# Assign a variable to the maximum number of games: 1, 3, 5, etc ...
# This time the previously defined function is used

max_games2 = odd_num 

# Assign a variable to the number of games a player must win to win.
# Preferably the value will be based on the number of maximum games

to_win2 = ((max_games2) / 2) + 0.5

# Define a function that randomly returns one of the 5 options.
# This will correspond to the play of the machine. Totally random.

def rdm_spsls():
    global cpu_option2
    cpu_option2 = random.choice(spsls)
    print(cpu_option2)
    

# Define a function that asks your choice between 5
# you should only allow one of the 5 options. This is defensive programming.
# If it is not valid, keep asking until it is valid.

def human2():
    global human_option2
    human_option2 = input('Choose stone, paper, scissors, lizard or spock: ')

    while human_option2 not in spsls:
        human_option2 = input("Choose stone, paper, scissors, lizard or spock: ")

# Define a function that resolves a combat.
# Returns 0 if there is a tie, 1 if the machine wins, 2 if the human player wins
# Now there are more options

def combat2():
    
    if human_option2 == cpu_option2:
        return 0
    
    elif human_option2 == 'stone':
        if cpu_option2 == 'paper':
            return 1
        if cpu_option2 == 'scissors':
            return 2
        if cpu_option2 == 'lizard':
            return 2
        if cpu_option2 == 'spock':
            return 1
        
    elif human_option2 == 'paper':
        if cpu_option2 == 'scissors':
            return 1
        if cpu_option2 == 'stone':
            return 2
        if cpu_option2 == 'lizard':
            return 2
        if cpu_option2 == 'spock':
            return 1
        
    elif human_option2 == 'scissors':
        if cpu_option2 == 'stone':
            return 1
        if cpu_option2 == 'paper':
            return 2
        if cpu_option2 == 'lizard':
            return 2
        if cpu_option2 == 'spock':
            return 1
        
    elif human_option2 == 'lizard':
        if cpu_option2 == 'stone':
            return 1
        if cpu_option2 == 'paper':
            return 2
        if cpu_option2 == 'scissors':
            return 1
        if cpu_option2 == 'spock':
            return 2
        
    elif human_option2 == 'spock':
        if cpu_option2 == 'stone':
            return 2
        if cpu_option2 == 'paper':
            return 1
        if cpu_option2 == 'lizard':
            return 1
        if cpu_option2 == 'scissors':
            return 2
            
# Define a function that shows the choice of each player and the state of the game
# This function should be used every time accumulated points are updated

def choices2():
    print('Cpu: ', cpu_option2)
    print('You: ' ,human_option2)
    print('CPU: ',  cpu_wins2, '  ','YOU: ', human_wins2, '  ', 'Ties: ', ties2)

# Create two variables that accumulate the wins of each participant

cpu_wins2 = 0
human_wins2 = 0
ties2 = 0

# Create a loop that iterates while no player reaches the minimum of wins
# necessary to win. Inside the loop solves the play of the
# machine and ask the player's. Compare them and update the value of the variables
# that accumulate the wins of each participant.
# Print by console the winner of the game based on who has more accumulated wins

while ((cpu_wins2 + human_wins2) < max_games2) and (cpu_wins2 < to_win2) and (human_wins2 < to_win2):
    
    rdm_spsls()
    
    human2()
    
    combat2()

    if combat2() == 1:
        cpu_wins2 = cpu_wins2 + 1
        
    elif combat2() == 2:
        human_wins2 = human_wins2 + 1
        
    elif combat2() == 0:
        ties2 = ties2 + 1
    
    choices2()
    
if cpu_wins2 > human_wins2:
    print ('CPU WINS')
elif human_wins2 > cpu_wins2:
    print ('YOU WIN')
# Out:
# 5
# Choose the number of games (odd number 1 to 9): 5
# Thats right!
# lizard
# Choose stone, paper, scissors, lizard or spock: stone
# Cpu:  lizard
# You:  stone
# CPU:  0    YOU:  1    Ties:  0
# paper
# Choose stone, paper, scissors, lizard or spock: scissors
# Cpu:  paper
# You:  scissors
# CPU:  0    YOU:  2    Ties:  0
# scissors
# Choose stone, paper, scissors, lizard or spock: stone
# Cpu:  scissors
# You:  stone
# CPU:  0    YOU:  3    Ties:  0
# YOU WIN
